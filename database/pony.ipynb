# %%
import os
import pandas as pd
from datetime import date
from pony.orm import *

db = Database()

# %%
# !pip install pony
# Out:
# Requirement already satisfied: pony in /home/timon/anaconda3/lib/python3.6/site-packages
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Define how to map tables to objects

# %%
class Station(db.Entity):
    stations_id = PrimaryKey(int, auto=False)
    von_datum = Optional(date)
    bis_datum = Optional(date)
    stationshoehe = Optional(int)
    geoBreite = Optional(float)
    geoLaenge = Optional(float)
    stationsname = Required(str)
    bundesland = Optional(str)
    measurements = Set('Measurement')


class Measurement(db.Entity):
    mess_datum = Required(int)      # have to set it to date later. sqlite has some problems with this
    stations_id = Required(Station)
    qn_3 = Optional(int)  # quality level of next columns
    fx = Optional(float)
    fm = Optional(float)
    qn_4 = Optional(int)
    rsk = Optional(float)
    rskf = Optional(float)
    sdk = Optional(float)
    shk_tag = Optional(float)
    nm = Optional(float)
    vpm = Optional(float)
    pm = Optional(float)
    tmk = Optional(float)
    upm = Optional(float)
    txk = Optional(float)
    tnk = Optional(float)
    tgk = Optional(float)
    PrimaryKey(mess_datum, stations_id)

# %%
db.bind(provider='sqlite', filename=os.path.abspath('./database.db'))

# %%
db.generate_mapping()

# %%
# if we want to generate the database tables using this
# db.generate_mapping(create_tables=True)

# %% [markdown]
# We already have the database set up by sqlalchemy, so we only want to query

# %%
stations = select(s for s in Station)

# %%
len(stations)
# Out:
# 2

# %%
for s in stations:
    print(s.stations_id, s.stationsname)
# Out:
# 1 Aach
# 3 Aachen

# %% [markdown]
# Pulling the whole measurements table into a list of objects and calculating the length is really slow

# %%
measurements = select(m for m in Measurement)

# %%
len(measurements)
# Out:
# 55788

# %% [markdown]
# Instead just count the measurements in the table

# %%
count(m for m in Measurement)
# Out:
# 55788

# %% [markdown]
# Filter for the measurements in Aach and only count those

# %%
count(s.measurements for s in Station if s.stationsname == 'Aach')
# Out:
# 17348

# %% [markdown]
# We can read whole tables into pandas without sqlalchemy or pony

# %%
pd.read_sql_table('measurement', 'sqlite:///database.db')
# Out:
#        mess_datum  stations_id  qn_3  fx  fm  qn_4   rsk  rskf  sdk  shk_tag  \
# 0        18910101            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 1        18910102            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 2        18910103            3   NaN NaN NaN     5   2.5   1.0  NaN      NaN
# 3        18910104            3   NaN NaN NaN     5   8.2   1.0  NaN      NaN
# 4        18910105            3   NaN NaN NaN     5   1.9   1.0  NaN      NaN
# 5        18910106            3   NaN NaN NaN     5   2.5   1.0  NaN      NaN
# 6        18910107            3   NaN NaN NaN     5   2.9   1.0  NaN      NaN
# 7        18910108            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 8        18910109            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 9        18910110            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 10       18910111            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 11       18910112            3   NaN NaN NaN     5   6.6   1.0  NaN      NaN
# 12       18910113            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 13       18910114            3   NaN NaN NaN     5   1.1   1.0  NaN      NaN
# 14       18910115            3   NaN NaN NaN     5   3.1   1.0  NaN      NaN
# 15       18910116            3   NaN NaN NaN     5   0.9   1.0  NaN      NaN
# 16       18910117            3   NaN NaN NaN     5   2.1   1.0  NaN      NaN
# 17       18910118            3   NaN NaN NaN     5   2.2   1.0  NaN      NaN
# 18       18910119            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 19       18910120            3   NaN NaN NaN     5  11.1   1.0  NaN      NaN
# 20       18910121            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 21       18910122            3   NaN NaN NaN     5   2.5   1.0  NaN      NaN
# 22       18910123            3   NaN NaN NaN     5  13.6   1.0  NaN      NaN
# 23       18910124            3   NaN NaN NaN     5   5.3   1.0  NaN      NaN
# 24       18910125            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 25       18910126            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 26       18910127            3   NaN NaN NaN     5   0.0   0.0  NaN      NaN
# 27       18910128            3   NaN NaN NaN     5   0.9   1.0  NaN      NaN
# 28       18910129            3   NaN NaN NaN     5   1.0   1.0  NaN      NaN
# 29       18910130            3   NaN NaN NaN     5   5.6   1.0  NaN      NaN
# ...           ...          ...   ...  ..  ..   ...   ...   ...  ...      ...
# 55758    19860601            1   NaN NaN NaN    10   9.9   6.0  NaN      0.0
# 55759    19860602            1   NaN NaN NaN    10   1.8   6.0  NaN      0.0
# 55760    19860603            1   NaN NaN NaN    10   8.5   6.0  NaN      0.0
# 55761    19860604            1   NaN NaN NaN    10  10.7   6.0  NaN      0.0
# 55762    19860605            1   NaN NaN NaN    10   5.1   8.0  NaN      0.0
# 55763    19860606            1   NaN NaN NaN    10   0.7   6.0  NaN      0.0
# 55764    19860607            1   NaN NaN NaN    10   0.6   6.0  NaN      0.0
# 55765    19860608            1   NaN NaN NaN    10   0.1   6.0  NaN      0.0
# 55766    19860609            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55767    19860610            1   NaN NaN NaN    10   0.1   6.0  NaN      0.0
# 55768    19860611            1   NaN NaN NaN    10  13.4   6.0  NaN      0.0
# 55769    19860612            1   NaN NaN NaN    10   1.0   6.0  NaN      0.0
# 55770    19860613            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55771    19860614            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55772    19860615            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55773    19860616            1   NaN NaN NaN    10   0.1   6.0  NaN      0.0
# 55774    19860617            1   NaN NaN NaN    10  19.0   6.0  NaN      0.0
# 55775    19860618            1   NaN NaN NaN    10   0.4   6.0  NaN      0.0
# 55776    19860619            1   NaN NaN NaN    10  24.0   6.0  NaN      0.0
# 55777    19860620            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55778    19860621            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55779    19860622            1   NaN NaN NaN    10   1.0   6.0  NaN      0.0
# 55780    19860623            1   NaN NaN NaN    10   5.0   6.0  NaN      0.0
# 55781    19860624            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55782    19860625            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55783    19860626            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55784    19860627            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55785    19860628            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55786    19860629            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
# 55787    19860630            1   NaN NaN NaN    10   0.0   0.0  NaN      0.0
#
#         nm   vpm  pm   tmk   upm   txk   tnk  tgk
# 0      0.0   4.3 NaN  -3.6  88.0   0.5  -5.9  NaN
# 1      2.7   4.1 NaN  -2.8  84.0   0.0  -5.8  NaN
# 2      3.7   3.9 NaN  -0.2  69.0   2.1  -6.2  NaN
# 3      8.0   6.4 NaN   1.8  90.0   3.7   0.6  NaN
# 4      7.7   4.7 NaN  -2.5  87.0   1.5  -4.2  NaN
# 5      8.0   3.5 NaN  -5.8  88.0  -4.0  -6.9  NaN
# 6      8.0   3.6 NaN  -5.8  94.0  -5.0  -7.7  NaN
# 7      6.7   3.7 NaN  -5.0  89.0  -3.5  -5.7  NaN
# 8      6.7   2.9 NaN  -7.8  87.0  -4.7  -9.2  NaN
# 9      3.7   2.1 NaN -11.4  85.0  -7.6 -12.7  NaN
# 10     4.0   3.1 NaN  -7.2  88.0  -5.6 -12.6  NaN
# 11     8.0   5.1 NaN   0.2  87.0   1.2  -5.8  NaN
# 12     2.7   5.6 NaN   0.4  86.0   2.8  -0.8  NaN
# 13     6.7   5.3 NaN   0.4  83.0   1.9  -2.3  NaN
# 14     5.0   4.0 NaN  -3.8  85.0   0.2  -5.0  NaN
# 15     5.7   2.9 NaN  -7.8  85.0  -4.0 -10.7  NaN
# 16     6.0   2.0 NaN -12.2  87.0  -8.0 -13.8  NaN
# 17     8.0   3.6 NaN  -6.0  94.0  -5.0 -12.4  NaN
# 18     6.0   3.7 NaN  -6.2  94.0  -4.0  -7.7  NaN
# 19     6.0   3.7 NaN  -4.2  87.0  -1.6 -10.2  NaN
# 20     6.3   5.3 NaN  -0.6  90.0   1.6  -2.8  NaN
# 21     6.7   5.2 NaN  -0.4  90.0   1.4  -2.5  NaN
# 22     7.0   5.5 NaN   3.0  76.0   5.0  -1.4  NaN
# 23     8.0   8.0 NaN   5.5  90.0   6.6   4.4  NaN
# 24     5.3   6.3 NaN   3.0  82.0   6.3   2.1  NaN
# 25     1.0   6.1 NaN   3.2  78.0   6.1   1.6  NaN
# 26     4.7   5.3 NaN   4.8  61.0   6.6   1.9  NaN
# 27     5.0   6.8 NaN   6.6  71.0   8.9   4.3  NaN
# 28     1.3   6.3 NaN   5.5  69.0   8.3   3.7  NaN
# 29     6.0   7.6 NaN   5.0  87.0   6.5   4.4  NaN
# ...    ...   ...  ..   ...   ...   ...   ...  ...
# 55758  7.7   9.0 NaN  10.2  75.0  15.3   5.4  NaN
# 55759  8.0  12.2 NaN  11.2  91.0  14.8   8.0  NaN
# 55760  6.0  10.9 NaN  12.9  74.0  19.4   6.9  NaN
# 55761  8.0   9.5 NaN   7.4  89.0  11.9   6.0  NaN
# 55762  7.0   8.3 NaN   7.6  78.0  13.0   4.9  NaN
# 55763  8.0   7.9 NaN   8.2  72.0  12.9   5.1  NaN
# 55764  8.0   8.9 NaN   7.8  84.0   8.7   3.9  NaN
# 55765  5.7  10.9 NaN  12.7  77.0  17.5   7.3  NaN
# 55766  2.7  11.3 NaN  15.6  68.0  22.0   5.6  NaN
# 55767  2.7  13.1 NaN  18.2  61.0  25.6   8.0  NaN
# 55768  8.0  12.8 NaN  11.5  91.0  17.5  10.0  NaN
# 55769  8.0  10.8 NaN  10.0  88.0  11.4   8.8  NaN
# 55770  8.0  11.1 NaN  10.7  86.0  12.0   8.9  NaN
# 55771  8.0  15.1 NaN  15.3  88.0  17.2  10.4  NaN
# 55772  3.3  17.7 NaN  21.8  68.0  26.2  15.4  NaN
# 55773  4.3  17.3 NaN  19.6  75.0  28.0  13.8  NaN
# 55774  6.3  16.4 NaN  19.4  73.0  26.8  14.9  NaN
# 55775  6.3  16.6 NaN  19.3  76.0  24.0  14.3  NaN
# 55776  6.3  17.0 NaN  20.3  70.0  27.1  14.0  NaN
# 55777  4.0  17.4 NaN  20.0  75.0  26.3  14.3  NaN
# 55778  2.0  18.4 NaN  21.0  74.0  28.0  13.8  NaN
# 55779  1.3  18.7 NaN  22.4  69.0  30.0  14.9  NaN
# 55780  4.0  19.1 NaN  21.8  71.0  30.4  16.9  NaN
# 55781  7.3  15.8 NaN  18.2  76.0  22.8  12.5  NaN
# 55782  2.3  14.2 NaN  20.1  60.0  24.8  11.5  NaN
# 55783  0.0  14.5 NaN  21.0  57.0  26.0  11.4  NaN
# 55784  0.0  14.1 NaN  20.6  58.0  28.0  11.3  NaN
# 55785  0.3  14.7 NaN  20.4  63.0  29.5  11.4  NaN
# 55786  1.3  15.1 NaN  21.6  59.0  29.0  13.0  NaN
# 55787  0.3  13.9 NaN  19.8  60.0  24.8  14.4  NaN
#
# [55788 rows x 18 columns]

# %% [markdown]
# But we can also read any query into a pandas dataframe by giving it the SQL query as text generated by pony

# %%
qu = select(s.measurements for s in Station if s.stationsname == 'Aach')

# %%
pd.read_sql(qu.get_sql(), 'sqlite:///database.db')
# Out:
#        mess_datum  stations_id  qn_3    fx    fm  qn_4   rsk  rskf   sdk  \
# 0        19370101            1  None  None  None     5   0.0   0.0  None
# 1        19370102            1  None  None  None     5   0.0   0.0  None
# 2        19370103            1  None  None  None     5   0.0   0.0  None
# 3        19370104            1  None  None  None     5   0.0   0.0  None
# 4        19370105            1  None  None  None     5   0.0   0.0  None
# 5        19370106            1  None  None  None     5   5.2   7.0  None
# 6        19370107            1  None  None  None     5   3.6   1.0  None
# 7        19370108            1  None  None  None     5   0.8   1.0  None
# 8        19370109            1  None  None  None     5   0.0   0.0  None
# 9        19370110            1  None  None  None     5   0.0   0.0  None
# 10       19370111            1  None  None  None     5   0.0   0.0  None
# 11       19370112            1  None  None  None     5   0.0   0.0  None
# 12       19370113            1  None  None  None     5   0.0   0.0  None
# 13       19370114            1  None  None  None     5   3.7   1.0  None
# 14       19370115            1  None  None  None     5   5.5   1.0  None
# 15       19370116            1  None  None  None     5   0.0   0.0  None
# 16       19370117            1  None  None  None     5   0.0   0.0  None
# 17       19370118            1  None  None  None     5   0.8   1.0  None
# 18       19370119            1  None  None  None     5  11.5   1.0  None
# 19       19370120            1  None  None  None     5   0.0   0.0  None
# 20       19370121            1  None  None  None     5   0.0   0.0  None
# 21       19370122            1  None  None  None     5   0.0   0.0  None
# 22       19370123            1  None  None  None     5   0.0   0.0  None
# 23       19370124            1  None  None  None     5   0.2   1.0  None
# 24       19370125            1  None  None  None     5   0.8   1.0  None
# 25       19370126            1  None  None  None     5   0.0   0.0  None
# 26       19370127            1  None  None  None     5   0.0   0.0  None
# 27       19370128            1  None  None  None     5   0.0   7.0  None
# 28       19370129            1  None  None  None     5  10.0   8.0  None
# 29       19370130            1  None  None  None     5   0.0   0.0  None
# ...           ...          ...   ...   ...   ...   ...   ...   ...   ...
# 17318    19860601            1  None  None  None    10   9.9   6.0  None
# 17319    19860602            1  None  None  None    10   1.8   6.0  None
# 17320    19860603            1  None  None  None    10   8.5   6.0  None
# 17321    19860604            1  None  None  None    10  10.7   6.0  None
# 17322    19860605            1  None  None  None    10   5.1   8.0  None
# 17323    19860606            1  None  None  None    10   0.7   6.0  None
# 17324    19860607            1  None  None  None    10   0.6   6.0  None
# 17325    19860608            1  None  None  None    10   0.1   6.0  None
# 17326    19860609            1  None  None  None    10   0.0   0.0  None
# 17327    19860610            1  None  None  None    10   0.1   6.0  None
# 17328    19860611            1  None  None  None    10  13.4   6.0  None
# 17329    19860612            1  None  None  None    10   1.0   6.0  None
# 17330    19860613            1  None  None  None    10   0.0   0.0  None
# 17331    19860614            1  None  None  None    10   0.0   0.0  None
# 17332    19860615            1  None  None  None    10   0.0   0.0  None
# 17333    19860616            1  None  None  None    10   0.1   6.0  None
# 17334    19860617            1  None  None  None    10  19.0   6.0  None
# 17335    19860618            1  None  None  None    10   0.4   6.0  None
# 17336    19860619            1  None  None  None    10  24.0   6.0  None
# 17337    19860620            1  None  None  None    10   0.0   0.0  None
# 17338    19860621            1  None  None  None    10   0.0   0.0  None
# 17339    19860622            1  None  None  None    10   1.0   6.0  None
# 17340    19860623            1  None  None  None    10   5.0   6.0  None
# 17341    19860624            1  None  None  None    10   0.0   0.0  None
# 17342    19860625            1  None  None  None    10   0.0   0.0  None
# 17343    19860626            1  None  None  None    10   0.0   0.0  None
# 17344    19860627            1  None  None  None    10   0.0   0.0  None
# 17345    19860628            1  None  None  None    10   0.0   0.0  None
# 17346    19860629            1  None  None  None    10   0.0   0.0  None
# 17347    19860630            1  None  None  None    10   0.0   0.0  None
#
#        shk_tag   nm   vpm    pm   tmk   upm   txk   tnk  tgk
# 0          0.0  6.3   NaN  None  -0.5   NaN   2.5  -1.6  NaN
# 1          0.0  3.0   NaN  None   0.3   NaN   5.0  -4.0  NaN
# 2          0.0  4.3   NaN  None   3.2   NaN   5.0  -0.2  NaN
# 3          0.0  8.0   NaN  None   0.2   NaN   3.8  -0.2  NaN
# 4          0.0  8.0   NaN  None   1.4   NaN   4.5  -0.7  NaN
# 5          0.0  6.0   NaN  None   0.2   NaN   2.0  -2.4  NaN
# 6          0.0  6.3   NaN  None   5.4   NaN   8.2   0.6  NaN
# 7          0.0  4.7   NaN  None   2.1   NaN   4.0   1.4  NaN
# 8          0.0  0.7   NaN  None  -1.6   NaN   1.6  -3.4  NaN
# 9          0.0  0.0   NaN  None  -3.0   NaN   1.4  -7.5  NaN
# 10         0.0  3.0   NaN  None  -3.3   NaN   0.4  -7.4  NaN
# 11         0.0  0.0   NaN  None  -4.0   NaN   1.0  -7.2  NaN
# 12         0.0  5.7   NaN  None  -2.4   NaN   2.4  -7.2  NaN
# 13         0.0  6.3   NaN  None  -1.3   NaN   0.0  -4.5  NaN
# 14         0.0  8.0   NaN  None   1.4   NaN   2.0  -0.4  NaN
# 15         0.0  8.0   NaN  None   1.1   NaN   2.5   0.5  NaN
# 16         0.0  6.0   NaN  None  -0.3   NaN   3.0  -1.4  NaN
# 17         0.0  8.0   NaN  None  -0.4   NaN   0.5  -2.0  NaN
# 18         0.0  7.3   NaN  None   3.0   NaN   5.6   0.4  NaN
# 19         0.0  5.0   NaN  None   0.7   NaN   4.0  -0.6  NaN
# 20         0.0  3.7   NaN  None  -1.4   NaN   3.0  -4.4  NaN
# 21         0.0  3.3   NaN  None   1.6   NaN   6.4  -1.4  NaN
# 22         0.0  0.0   NaN  None   0.4   NaN   6.2  -2.2  NaN
# 23         0.0  5.0   NaN  None  -2.6   NaN   1.3  -3.2  NaN
# 24         0.0  7.3   NaN  None  -1.4   NaN   0.0  -3.2  NaN
# 25         0.0  3.3   NaN  None   1.0   NaN   8.6  -3.4  NaN
# 26         0.0  4.7   NaN  None  -1.3   NaN   1.2  -2.2  NaN
# 27         0.0  6.3   NaN  None  -4.0   NaN  -1.6  -4.6  NaN
# 28         0.0  8.0   NaN  None  -1.3   NaN   0.6  -5.0  NaN
# 29         5.0  4.7   NaN  None   2.0   NaN   6.6   0.5  NaN
# ...        ...  ...   ...   ...   ...   ...   ...   ...  ...
# 17318      0.0  7.7   9.0  None  10.2  75.0  15.3   5.4  NaN
# 17319      0.0  8.0  12.2  None  11.2  91.0  14.8   8.0  NaN
# 17320      0.0  6.0  10.9  None  12.9  74.0  19.4   6.9  NaN
# 17321      0.0  8.0   9.5  None   7.4  89.0  11.9   6.0  NaN
# 17322      0.0  7.0   8.3  None   7.6  78.0  13.0   4.9  NaN
# 17323      0.0  8.0   7.9  None   8.2  72.0  12.9   5.1  NaN
# 17324      0.0  8.0   8.9  None   7.8  84.0   8.7   3.9  NaN
# 17325      0.0  5.7  10.9  None  12.7  77.0  17.5   7.3  NaN
# 17326      0.0  2.7  11.3  None  15.6  68.0  22.0   5.6  NaN
# 17327      0.0  2.7  13.1  None  18.2  61.0  25.6   8.0  NaN
# 17328      0.0  8.0  12.8  None  11.5  91.0  17.5  10.0  NaN
# 17329      0.0  8.0  10.8  None  10.0  88.0  11.4   8.8  NaN
# 17330      0.0  8.0  11.1  None  10.7  86.0  12.0   8.9  NaN
# 17331      0.0  8.0  15.1  None  15.3  88.0  17.2  10.4  NaN
# 17332      0.0  3.3  17.7  None  21.8  68.0  26.2  15.4  NaN
# 17333      0.0  4.3  17.3  None  19.6  75.0  28.0  13.8  NaN
# 17334      0.0  6.3  16.4  None  19.4  73.0  26.8  14.9  NaN
# 17335      0.0  6.3  16.6  None  19.3  76.0  24.0  14.3  NaN
# 17336      0.0  6.3  17.0  None  20.3  70.0  27.1  14.0  NaN
# 17337      0.0  4.0  17.4  None  20.0  75.0  26.3  14.3  NaN
# 17338      0.0  2.0  18.4  None  21.0  74.0  28.0  13.8  NaN
# 17339      0.0  1.3  18.7  None  22.4  69.0  30.0  14.9  NaN
# 17340      0.0  4.0  19.1  None  21.8  71.0  30.4  16.9  NaN
# 17341      0.0  7.3  15.8  None  18.2  76.0  22.8  12.5  NaN
# 17342      0.0  2.3  14.2  None  20.1  60.0  24.8  11.5  NaN
# 17343      0.0  0.0  14.5  None  21.0  57.0  26.0  11.4  NaN
# 17344      0.0  0.0  14.1  None  20.6  58.0  28.0  11.3  NaN
# 17345      0.0  0.3  14.7  None  20.4  63.0  29.5  11.4  NaN
# 17346      0.0  1.3  15.1  None  21.6  59.0  29.0  13.0  NaN
# 17347      0.0  0.3  13.9  None  19.8  60.0  24.8  14.4  NaN
#
# [17348 rows x 18 columns]

# %%
quc = select(count(s.measurements) for s in Station if s.stationsname == 'Aach')
pd.read_sql(quc.get_sql(), 'sqlite:///database.db')
# Out:
#    COUNT("measurement"."ROWID")
# 0                         17348

# %%
old_measurements = select(m for m in Measurement if m.stations_id.stationsname == 'Aachen' and m.mess_datum < 19000101)

# %%
for m in old_measurements[:5]:
    print(m)
# Out:
# Measurement[18910101,Station[3]]
# Measurement[18910102,Station[3]]
# Measurement[18910103,Station[3]]
# Measurement[18910104,Station[3]]
# Measurement[18910105,Station[3]]

# %% [markdown]
# It looks a bit weird when we reference the station of a measurement as stations_id. Could redesign that if we use this pony

# %%
old_measurements.
# Out:
# <bound method count of <pony.orm.core.Query object at 0x7faceff9beb8>>
